# %%
import os
import pandas as pd
import re

# %%
path_livros = os.path.join("dataset", "archive", "Brazilian_Portugese_Corpus")

# %%
with open(os.path.join(path_livros, "A Normalista.txt"), "r") as file:
    raw_moreninha = file.read()

# %%
palavras_moreninhas = re.split(r"\s+", raw_moreninha)

# %%
len(palavras_moreninhas)

# %%
len(set(palavras_moreninhas))
# Out:
# 15445

# %%
df_palavras = pd.DataFrame(palavras_moreninhas, columns=["palavra"])

# %%
df_palavras["palavra"].value_counts().reset_index().tail(50)
# Out:
#                  palavra  count
# 15395          queixando      1
# 15396              lenta      1
# 15397          secretas.      1
# 15398        Levantou-se      1
# 15399             agonia      1
# 15400  espreguiçando-se.      1
# 15401       pesadamente.      1
# 15402            herdara      1
# 15403                 Ma      1
# 15404             cabine      1
# 15405           coucher,      1
# 15406             boêmio      1
# 15407     confundindo-se      1
# 15408        ilustrados,      1
# 15409     porta-retratos      1
# 15410        fotografias      1
# 15411            esposa,      1
# 15412           sentidos      1
# 15413           opostos.      1
# 15414         "gabinete"      1
# 15415            remanso      1
# 15416         cuidadoso.      1
# 15417            juritis      1
# 15418             pedra;      1
# 15419            gabava;      1
# 15420              duros      1
# 15421            desejar      1
# 15422         escritores      1
# ...
